# %% [markdown]
# <a href="https://colab.research.google.com/github/Stanou7/DemoProjet/blob/main/ML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('SaYoPillow.csv')
df
# Out:
#      snoring_range  respiration_rate  body_temperature  limb_movement_rate  \
# 0           93.800            25.680            91.840              16.600
# 1           91.640            25.104            91.552              15.880
# 2           60.000            20.000            96.000              10.000
# 3           85.760            23.536            90.768              13.920
# 4           48.120            17.248            97.872               6.496
# ..             ...               ...               ...                 ...
# 625         69.600            20.960            92.960              10.960
# 626         48.440            17.376            98.064               6.752
# 627         97.504            27.504            86.880              17.752
# 628         58.640            19.728            95.728               9.728
# 629         73.920            21.392            93.392              11.392
#
# ...

# %%
df.max()
# Out:
# snoring_range          100.0
# respiration_rate        30.0
# body_temperature        99.0
# limb_movement_rate      19.0
# blood_oxygen_levels     97.0
# rapid_eye_movement     105.0
# hour_of_sleep            9.0
# heart_rate              85.0
# stress_level             4.0
# dtype: float64

# %%
df.min()
# Out:
# snoring_range          45.0
# respiration_rate       16.0
# body_temperature       85.0
# limb_movement_rate      4.0
# blood_oxygen_levels    82.0
# rapid_eye_movement     60.0
# hour_of_sleep           0.0
# heart_rate             50.0
# stress_level            0.0
# dtype: float64

# %%
df.mean()
# Out:
# snoring_range          71.6
# respiration_rate       21.8
# body_temperature       92.8
# limb_movement_rate     11.7
# blood_oxygen_levels    90.9
# rapid_eye_movement     88.5
# hour_of_sleep           3.7
# heart_rate             64.5
# stress_level            2.0
# dtype: float64

# %%
df.median()
# Out:
# snoring_range          70.0
# respiration_rate       21.0
# body_temperature       93.0
# limb_movement_rate     11.0
# blood_oxygen_levels    91.0
# rapid_eye_movement     90.0
# hour_of_sleep           3.5
# heart_rate             62.5
# stress_level            2.0
# dtype: float64

# %%
import seaborn as sns

# %%
sns.countplot(df, x='stress_level')
# Out:
# <Axes: xlabel='stress_level', ylabel='count'>

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='stress_level')

# %%
from sklearn.model_selection import train_test_split

# %%
X= df.drop('stress_level', axis=1)
y= df['stress_level']

# %%
X_train, X_test, y_train, y_test = train_test_split (X,y, test_size=0.2, random_state=0)

# %%
X.count()
# Out:
# snoring_range          630
# respiration_rate       630
# body_temperature       630
# limb_movement_rate     630
# blood_oxygen_levels    630
# rapid_eye_movement     630
# hour_of_sleep          630
# heart_rate             630
# dtype: int64

# %%
X_train.count()
# Out:
# snoring_range          504
# respiration_rate       504
# body_temperature       504
# limb_movement_rate     504
# blood_oxygen_levels    504
# rapid_eye_movement     504
# hour_of_sleep          504
# heart_rate             504
# dtype: int64

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
y_prd = knn.predict(X_test)

# %%
from sklearn .metrics import confusion_matrix

# %%
confusion_mat_result = confusion_matrix (y_prd, y_test)

# %%
sns.heatmap(confusion_mat_result, annot=True)
# Out:
# <Axes: >

# %% [markdown]
# DecisionTree

# %%
from sklearn import tree

# %%
clf= tree.DecisionTreeClassifier()
clf
# Out:
# DecisionTreeClassifier()

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split (X,y, test_size=0.2, random_state=0)

# %%
clf.fit(X_train1,y_train1)
# Out:
# DecisionTreeClassifier()

# %%
y_prd1 = clf.predict(X_test1)
y_prd1
# Out:
# array([1, 1, 2, 3, 0, 2, 3, 4, 3, 2, 0, 0, 0, 0, 1, 3, 4, 3, 4, 1, 4, 4,
#        3, 4, 4, 3, 1, 1, 1, 3, 4, 1, 4, 3, 2, 2, 0, 4, 2, 0, 0, 1, 3, 0,
#        2, 1, 0, 3, 0, 1, 4, 0, 0, 3, 0, 0, 1, 4, 2, 3, 1, 2, 3, 2, 3, 2,
#        3, 4, 3, 0, 4, 0, 3, 0, 4, 4, 2, 4, 3, 4, 1, 4, 0, 3, 0, 4, 4, 1,
#        4, 4, 0, 3, 1, 3, 4, 4, 1, 2, 3, 1, 2, 2, 2, 4, 1, 0, 3, 4, 1, 0,
#        0, 4, 0, 2, 4, 3, 0, 0, 0, 2, 3, 2, 2, 2, 3, 3])

# %%
tree.plot_tree(clf)
# Out:
# [Text(0.5, 0.875, 'x[5] <= 85.04\ngini = 0.8\nsamples = 504\nvalue = [98, 107, 104, 98, 97]'),
#  Text(0.2, 0.625, 'x[6] <= 6.992\ngini = 0.499\nsamples = 205\nvalue = [98, 107, 0, 0, 0]'),
#  Text(0.1, 0.375, 'gini = 0.0\nsamples = 106\nvalue = [0, 106, 0, 0, 0]'),
#  Text(0.3, 0.375, 'x[0] <= 55.0\ngini = 0.02\nsamples = 99\nvalue = [98, 1, 0, 0, 0]'),
#  Text(0.2, 0.125, 'gini = 0.0\nsamples = 98\nvalue = [98, 0, 0, 0, 0]'),
#  Text(0.4, 0.125, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0]'),
#  Text(0.8, 0.625, 'x[6] <= 2.012\ngini = 0.666\nsamples = 299\nvalue = [0, 0, 104, 98, 97]'),
#  Text(0.7, 0.375, 'x[0] <= 95.5\ngini = 0.5\nsamples = 195\nvalue = [0, 0, 0, 98, 97]'),
#  Text(0.6, 0.125, 'gini = 0.0\nsamples = 98\nvalue = [0, 0, 0, 98, 0]'),
#  Text(0.8, 0.125, 'gini = 0.0\nsamples = 97\nvalue = [0, 0, 0, 0, 97]'),
#  Text(0.9, 0.375, 'gini = 0.0\nsamples = 104\nvalue = [0, 0, 104, 0, 0]')]
